# %%
import bokeh.io
import examples.weather_data_explorer

# %%
bokeh.io.output_notebook()
application = examples.weather_data_explorer.WeatherDataExplorer()
bokeh.io.show(application)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# <script id="1002">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:56320/autoload.js?bokeh-autoload-element=1002&bokeh-absolute-url=http://localhost:56320&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>
# Post handled

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined
